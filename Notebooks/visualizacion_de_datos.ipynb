# %% [markdown]
# Visualización de Datos

# %%
#Importar librerias 
#!pip3 install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 3.4 MB/s eta 0:00:0000:0100:010m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.3/241.3 kB 4.4 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 960.0/960.0 kB 5.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 3.9 MB/s eta 0:00:0000:0100:01
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Scatter plot  (diagrams de dispersion)
from turtle import title


x = np.arange(1, 20)
y = x**2

#plt.scatter(x, y)
#plt.scatter(x, y, color='red')
#plt.scatter(x, y, color='red', marker='*')
#plt.scatter(x, y, color='red', marker='s')
plt.scatter(x, y, color='red', marker='s', label='x^2', s=10)
plt.legend(title='funciones')
plt.title('Tipo de funciones', fontsize=20)
plt.xlabel('x', color='green')
plt.ylabel('y')
plt.grid()
